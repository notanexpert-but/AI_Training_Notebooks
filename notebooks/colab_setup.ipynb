# %% [markdown]
# <a href="https://colab.research.google.com/github/notanexpert-but/AI_Training_Notebooks/blob/main/notebooks/colab_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Oscar! Colab is ready.")
# Out:
# Hello, Oscar! Colab is ready.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Path inside your Google Drive
base_path = "/content/drive/MyDrive/AI_Training"

# Create the folder if it doesn't exist
os.makedirs(base_path, exist_ok=True)
print("✅ Folder created at:", base_path)
# Out:
# ✅ Folder created at: /content/drive/MyDrive/AI_Training
